# %%
import pandas as pd
import sqlite3

conn=sqlite3.connect(r'C:\Users\s3309\Website\AT_WEB\db\db.sqlite3')
news=pd.read_sql(r'Select * from News',conn)

# %%
#filter out data don't want
news=news[~news['Tags'].str.contains('盤前|趨勢分析',regex=True)]
news
# Out:
#           id              Date                                Headline  \
# 0          1  2022/08/10 21:49  樺漢子公司Kontron出售部分IT Service業務 處分利益近60億元
# 1          2  2022/08/10 21:00         〈三星新機發表〉兩款摺疊新機提升相機規格 8/26特定市場上市
# 2          3  2022/08/10 21:42           〈稅收統計〉房市降溫？7月土增稅年減近3成 連續4個月衰退
# 3          4  2022/08/10 20:56        〈稅收統計〉營所稅+綜所稅挹注 7月稅收6923億元 年增22%
# 4          5  2022/08/10 19:40                     旺季助攻 超商雙雄7月營收同寫新高紀錄
# ...      ...               ...                                     ...
# 14004  14102  2021/12/17 08:00               操盤手看台股：元宇宙下一步看生態圈 首波選股看誰？
# 14005  14103  2021/12/17 10:55              東森集團全年獲利倍增衝破50億元 年終獎金最高6個月
# 14006  14104  2021/12/17 10:35          台股基金規模挑戰高收益債 高股息ETF貢獻高 元月除息秀可期
# 14007  14105  2021/12/17 06:00     〈台股盤前要聞〉聯發科看好未來5年、央行第四波打炒房 今日必看財經新聞
# 14008  14106  2021/12/21 13:42           電金傳權值回神 台股漲120點收17789點 收復所有均線
#
#                        Tags                                            Content
# ...

# %%
n
